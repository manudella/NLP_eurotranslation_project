# %%
# Create a directory and clone the Github MT-Preparation repository
# !mkdir -p nmt
# %cd nmt
# !git clone https://github.com/ymoslem/MT-Preparation.git
# Out:
# /content/nmt
# Cloning into 'MT-Preparation'...
# remote: Enumerating objects: 227, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 227 (delta 115), reused 186 (delta 94), pack-reused 0
# Receiving objects: 100% (227/227), 54.89 KiB | 4.99 MiB/s, done.
# Resolving deltas: 100% (115/115), done.

# %%
# Install the requirements
# !pip3 install -r MT-Preparation/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Download and unzip a dataset
# !unzip /content/drive/MyDrive/NLP_Project/en_es/en-es.txt.zip
# Out:
# Archive:  /content/drive/MyDrive/NLP_Project/en_es/en-es.txt.zip
#   inflating: README
#   inflating: LICENSE
#   inflating: Europarl.en-es.en
#   inflating: Europarl.en-es.es
#   inflating: Europarl.en-es.xml

# %%
# Filter the dataset
# Arguments: source file, target file, source language, target language
# !python3 MT-Preparation/filtering/filter.py Europarl.en-es.es Europarl.en-es.en es en
# Out:
# Dataframe shape (rows, columns): (2009073, 2)
# --- Rows with Empty Cells Deleted	--> Rows: 2009073
# --- Duplicates Deleted			--> Rows: 1962064
# --- Source-Copied Rows Deleted		--> Rows: 1961573
# --- Too Long Source/Target Deleted	--> Rows: 1951145
# --- HTML Removed			--> Rows: 1951145
# --- Rows will remain in true-cased	--> Rows: 1951145
# --- Rows with Empty Cells Deleted	--> Rows: 1951145
# --- Rows Shuffled			--> Rows: 1951145
# --- Source Saved: Europarl.en-es.es-filtered.es
# --- Target Saved: Europarl.en-es.en-filtered.en

# %%
# !ls MT-Preparation/subwording/
# Out:
# 1-train_bpe.py	1-train_unigram.py  2-subword.py  3-desubword.py

# %%
# Train a SentencePiece model for subword tokenization
# !python3 MT-Preparation/subwording/1-train_unigram.py Europarl.en-es.es-filtered.es Europarl.en-es.en-filtered.en
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=Europarl.en-es.es-filtered.es --model_prefix=source --vocab_size=50000 --hard_vocab_limit=false --split_digits=true
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: Europarl.en-es.es-filtered.es
#   input_format:
#   model_prefix: source
#   model_type: UNIGRAM
#   vocab_size: 50000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 1
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
# ...

# %%
# !ls
# Out:
# Europarl.en-es.en	       Europarl.en-es.xml  source.model
# Europarl.en-es.en-filtered.en  LICENSE		   source.vocab
# Europarl.en-es.es	       MT-Preparation	   target.model
# Europarl.en-es.es-filtered.es  README		   target.vocab

# %%
# Subword the dataset
# !python3 MT-Preparation/subwording/2-subword.py source.model target.model Europarl.en-es.es-filtered.es Europarl.en-es.en-filtered.en
# Out:
# Source Model: source.model
# Target Model: target.model
# Source Dataset: Europarl.en-es.es-filtered.es
# Target Dataset: Europarl.en-es.en-filtered.en
# Done subwording the source file! Output: Europarl.en-es.es-filtered.es.subword
# Done subwording the target file! Output: Europarl.en-es.en-filtered.en.subword

# %%
# First 3 lines before subwording
# !head -n 3 Europarl.en-es.es-filtered.es && echo "-----" && head -n 3 Europarl.en-es.en-filtered.en
# Out:
# Beka perdió parte de su cráneo y la granada sigue dentro.
# En segundo lugar, contribuye a asegurar la cohesión territorial a través de un conjunto de disposiciones que ayudarán a las regiones de la Unión a gestionar su propio desarrollo.
# Señor Presidente en ejercicio, estoy segura de que esperará que en esta Asamblea expresemos una opinión equilibrada del proyecto de propuestas y no voy a decepcionarlo.
# -----
# Beka lost part of his skull and shrapnel remains inside.
# Secondly, it helps ensure territorial cohesion by means of a set of provisions that will help the EU’s regions to manage their own development.
# Mr President-in-Office, I am sure you would expect us, in this House, to express a balanced view of the draft proposals, and I will not disappoint you.

# %%
# First 3 lines after subwording
# !head -n 3 Europarl.en-es.es-filtered.es.subword && echo "---" && head -n 3 Europarl.en-es.en-filtered.en.subword
# Out:
# ▁Be ka ▁perdió ▁parte ▁de ▁su ▁cráneo ▁y ▁la ▁gran ada ▁sigue ▁dentro .
# ▁En ▁segundo ▁lugar , ▁contribuye ▁a ▁asegurar ▁la ▁cohesión ▁territorial ▁a ▁través ▁de ▁un ▁conjunto ▁de ▁disposiciones ▁que ▁ayudarán ▁a ▁las ▁regiones ▁de ▁la ▁Unión ▁a ▁gestionar ▁su ▁propio ▁desarrollo .
# ▁Señor ▁Presidente ▁en ▁ejercicio , ▁estoy ▁segura ▁de ▁que ▁esperará ▁que ▁en ▁esta ▁Asamblea ▁expresemos ▁una ▁opinión ▁equilibrada ▁del ▁proyecto ▁de ▁propuestas ▁y ▁no ▁voy ▁a ▁decepcionar lo .
# ---
# ▁Beka ▁lost ▁part ▁of ▁his ▁skull ▁and ▁shrapnel ▁remains ▁inside .
# ▁Secondly , ▁it ▁helps ▁ensure ▁territorial ▁cohesion ▁by ▁means ▁of ▁a ▁set ▁of ▁provisions ▁that ▁will ▁help ▁the ▁EU ’ s ▁regions ▁to ▁manage ▁their ▁own ▁development .
# ▁Mr ▁President - in - Office , ▁I ▁am ▁sure ▁you ▁would ▁expect ▁us , ▁in ▁this ▁House , ▁to ▁express ▁a ▁balanced ▁view ▁of ▁the ▁draft ▁proposals , ▁and ▁I ▁will ▁not ▁disappoint ▁you .

# %%
# Split the dataset into training set, development set, and test set
# Development and test sets should be between 1000 and 5000 segments (here we chose 2000)
# !python3 MT-Preparation/train_dev_split/train_dev_test_split.py 4000 4000 Europarl.en-es.es-filtered.es.subword Europarl.en-es.en-filtered.en.subword
# Out:
# Dataframe shape: (1951145, 2)
# --- Empty Cells Deleted --> Rows: 1951145
# --- Wrote Files
# Done!
# Output files
# Europarl.en-es.es-filtered.es.subword.train
# Europarl.en-es.en-filtered.en.subword.train
# Europarl.en-es.es-filtered.es.subword.dev
# Europarl.en-es.en-filtered.en.subword.dev
# Europarl.en-es.es-filtered.es.subword.test
# Europarl.en-es.en-filtered.en.subword.test

# %%
# Line count for the subworded train, dev, test datatest
# !wc -l *.subword.*
# Out:
#      4000 Europarl.en-es.en-filtered.en.subword.dev
#      4000 Europarl.en-es.en-filtered.en.subword.test
#   1943145 Europarl.en-es.en-filtered.en.subword.train
#      4000 Europarl.en-es.es-filtered.es.subword.dev
#      4000 Europarl.en-es.es-filtered.es.subword.test
#   1943145 Europarl.en-es.es-filtered.es.subword.train
#   3902290 total

# %%
# Check the first and last line from each dataset

# -------------------------------------------
# Change this cell to print your name
# !echo -e "My name is: Manuel Piessalbo \n"
# -------------------------------------------

# !echo "---First line---"
# !head -n 1 *.{train,dev,test}

# !echo -e "\n---Last line---"
# !tail -n 1 *.{train,dev,test}
# Out:
# My name is: Manuel Piessalbo
#
# ---First line---
# ==> Europarl.en-es.en-filtered.en.subword.train <==
# ▁Beka ▁lost ▁part ▁of ▁his ▁skull ▁and ▁shrapnel ▁remains ▁inside .
#
# ==> Europarl.en-es.es-filtered.es.subword.train <==
# ▁Be ka ▁perdió ▁parte ▁de ▁su ▁cráneo ▁y ▁la ▁gran ada ▁sigue ▁dentro .
#
# ==> Europarl.en-es.en-filtered.en.subword.dev <==
# ▁We ▁have ▁no ▁defined ▁limits ▁for ▁the ▁addition ▁of ▁water ▁to ▁wine , ▁but , ▁for ▁example , ▁a ▁limit ▁of ▁ 7 % ▁has ▁been ▁defined ▁in ▁respect ▁of ▁adding ▁water ▁to ▁concentrated ▁grapes , ▁as ▁it ▁is ▁impossible ▁to ▁detect ▁the ▁addition ▁of ▁water ▁below ▁that ▁threshold .
#
# ==> Europarl.en-es.es-filtered.es.subword.dev <==
# ▁No ▁tenemos ▁límites ▁definidos ▁para ▁la ▁adición ▁de ▁agua ▁al ▁vino , ▁pero , ▁por ▁ejemplo , ▁se ▁ha ▁fijado ▁un ▁límite ▁del ▁ 7 ▁% ▁para ▁la ▁adición ▁de ▁agua ▁al ▁zumo ▁de ▁uva ▁concentrado , ▁ya ▁que ▁resulta ▁imposible ▁detectar ▁toda ▁adición ▁de ▁agua ▁inferior ▁a ▁ese ▁umbral .
#
# ...

# %%
# Copy your data to your Google Drive
# !cp -R /content/nmt/ /content/drive/MyDrive/NLP_Project/en_es/es_to_en
