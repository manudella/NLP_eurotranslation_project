# %%
# Create a directory and clone the Github MT-Preparation repository
# !mkdir -p nmt2
# %cd nmt2
# !git clone https://github.com/ymoslem/MT-Preparation.git
# Out:
# /content/nmt2
# Cloning into 'MT-Preparation'...
# remote: Enumerating objects: 227, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 227 (delta 115), reused 186 (delta 94), pack-reused 0
# Receiving objects: 100% (227/227), 54.89 KiB | 2.29 MiB/s, done.
# Resolving deltas: 100% (115/115), done.

# %%
# Install the requirements
# !pip3 install -r MT-Preparation/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Download and unzip a dataset
# !unzip /content/drive/MyDrive/NLP_Project/en_de/de-en.txt.zip
# Out:
# Archive:  /content/drive/MyDrive/NLP_Project/en_de/de-en.txt.zip
#   inflating: README
#   inflating: LICENSE
#   inflating: Europarl.de-en.de
#   inflating: Europarl.de-en.en
#   inflating: Europarl.de-en.xml

# %%
# Filter the dataset
# Arguments: source file, target file, source language, target language
# !python3 MT-Preparation/filtering/filter.py Europarl.de-en.de Europarl.de-en.en de en
# Out:
# Dataframe shape (rows, columns): (1961119, 2)
# --- Rows with Empty Cells Deleted	--> Rows: 1961119
# --- Duplicates Deleted			--> Rows: 1916742
# --- Source-Copied Rows Deleted		--> Rows: 1916267
# --- Too Long Source/Target Deleted	--> Rows: 1901539
# --- HTML Removed			--> Rows: 1901539
# --- Rows will remain in true-cased	--> Rows: 1901539
# --- Rows with Empty Cells Deleted	--> Rows: 1901539
# --- Rows Shuffled			--> Rows: 1901539
# --- Source Saved: Europarl.de-en.de-filtered.de
# --- Target Saved: Europarl.de-en.en-filtered.en

# %%
# !ls MT-Preparation/subwording/
# Out:
# 1-train_bpe.py	1-train_unigram.py  2-subword.py  3-desubword.py

# %%
# Train a SentencePiece model for subword tokenization
# !python3 MT-Preparation/subwording/1-train_unigram.py Europarl.de-en.de-filtered.de Europarl.de-en.en-filtered.en
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=Europarl.de-en.de-filtered.de --model_prefix=source --vocab_size=50000 --hard_vocab_limit=false --split_digits=true
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: Europarl.de-en.de-filtered.de
#   input_format:
#   model_prefix: source
#   model_type: UNIGRAM
#   vocab_size: 50000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 1
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
# ...

# %%
# !ls
# Out:
# Europarl.de-en.de	       Europarl.de-en.xml  source.model
# Europarl.de-en.de-filtered.de  LICENSE		   source.vocab
# Europarl.de-en.en	       MT-Preparation	   target.model
# Europarl.de-en.en-filtered.en  README		   target.vocab

# %%
# Subword the dataset
# !python3 MT-Preparation/subwording/2-subword.py source.model target.model Europarl.de-en.de-filtered.de Europarl.de-en.en-filtered.en
# Out:
# Source Model: source.model
# Target Model: target.model
# Source Dataset: Europarl.de-en.de-filtered.de
# Target Dataset: Europarl.de-en.en-filtered.en
# Done subwording the source file! Output: Europarl.de-en.de-filtered.de.subword
# Done subwording the target file! Output: Europarl.de-en.en-filtered.en.subword

# %%
# First 3 lines before subwording
# !head -n 3 Europarl.en-it.en-filtered.en && echo "-----" && head -n 3 Europarl.en-it.it-filtered.it
# Out:
# head: cannot open 'Europarl.en-it.en-filtered.en' for reading: No such file or directory

# %%
# First 3 lines after subwording
# !head -n 3 Europarl.en-it.en-filtered.en.subword && echo "---" && head -n 3 Europarl.en-it.it-filtered.it.subword
# Out:
# ▁Despite ▁that ▁selective ▁approach , ▁it ▁is ▁good ▁that ▁crimes ▁should ▁be ▁punished , ▁even ▁if ▁an ▁attempt ▁is ▁made ▁to ▁justify ▁them ▁in ▁terms ▁of ▁the ▁exigencies ▁of ▁war .
# ▁( IT ) ▁I ▁have ▁received ▁a ▁request ▁from ▁Mr ▁Hannan ▁for ▁an ▁item ▁on ▁the ▁interpretation ▁of ▁Rule ▁ 1 9 ▁of ▁our ▁Rules ▁of ▁Procedure .
# ▁The ▁support ▁of ▁the ▁British ▁Conservatives ▁once ▁again ▁clearly ▁shows ▁the ▁untenable ▁association ▁of ▁this ▁group ▁with ▁the ▁European ▁People ’ s ▁Party ▁tradition , ▁so ▁well ▁represented ▁by ▁Mrs ▁Gross et ê te ▁and ▁also ▁by ▁Mrs ▁Avil é s ▁Perea .
# ---
# ▁Nonostante ▁questo ▁approccio ▁selettivo , ▁è ▁positivo ▁che ▁i ▁crimini ▁vengano ▁puniti , ▁anche ▁se ▁si ▁tenta ▁di ▁giustifica rli ▁in ▁termini ▁di ▁esigenze ▁di ▁guerra .
# ▁Ho ▁ricevuto ▁una ▁richiesta ▁dall ' onorevole ▁Hannan ▁per ▁un ▁punto ▁riguardante ▁l ' interpretazione ▁dell ' articolo ▁ 1 9 ▁del ▁nostro ▁regolamento .
# ...

# %%
# Split the dataset into training set, development set, and test set
# Development and test sets should be between 1000 and 5000 segments (here we chose 2000)
# !python3 MT-Preparation/train_dev_split/train_dev_test_split.py 4000 4000 Europarl.de-en.de-filtered.de.subword Europarl.de-en.en-filtered.en.subword
# Out:
# Dataframe shape: (1901539, 2)
# --- Empty Cells Deleted --> Rows: 1901539
# --- Wrote Files
# Done!
# Output files
# Europarl.de-en.de-filtered.de.subword.train
# Europarl.de-en.en-filtered.en.subword.train
# Europarl.de-en.de-filtered.de.subword.dev
# Europarl.de-en.en-filtered.en.subword.dev
# Europarl.de-en.de-filtered.de.subword.test
# Europarl.de-en.en-filtered.en.subword.test

# %%
# Line count for the subworded train, dev, test datatest
# !wc -l *.subword.*
# Out:
#      4000 Europarl.de-en.de-filtered.de.subword.dev
#      4000 Europarl.de-en.de-filtered.de.subword.test
#   1893539 Europarl.de-en.de-filtered.de.subword.train
#      4000 Europarl.de-en.en-filtered.en.subword.dev
#      4000 Europarl.de-en.en-filtered.en.subword.test
#   1893539 Europarl.de-en.en-filtered.en.subword.train
#   3803078 total

# %%
# Check the first and last line from each dataset

# -------------------------------------------
# Change this cell to print your name
# !echo -e "My name is: Manuel Piessalbo \n"
# -------------------------------------------

# !echo "---First line---"
# !head -n 1 *.{train,dev,test}

# !echo -e "\n---Last line---"
# !tail -n 1 *.{train,dev,test}
# Out:
# My name is: Manuel Piessalbo
#
# ---First line---
# ==> Europarl.en-it.en-filtered.en.subword.train <==
# ▁Despite ▁that ▁selective ▁approach , ▁it ▁is ▁good ▁that ▁crimes ▁should ▁be ▁punished , ▁even ▁if ▁an ▁attempt ▁is ▁made ▁to ▁justify ▁them ▁in ▁terms ▁of ▁the ▁exigencies ▁of ▁war .
#
# ==> Europarl.en-it.it-filtered.it.subword.train <==
# ▁Nonostante ▁questo ▁approccio ▁selettivo , ▁è ▁positivo ▁che ▁i ▁crimini ▁vengano ▁puniti , ▁anche ▁se ▁si ▁tenta ▁di ▁giustifica rli ▁in ▁termini ▁di ▁esigenze ▁di ▁guerra .
#
# ==> Europarl.en-it.en-filtered.en.subword.dev <==
# ▁The ▁explanatory ▁statement ▁is ▁very ▁precise ▁in ▁describing ▁what ▁is ▁happening ▁at ▁the ▁moment , ▁namely ▁that ▁judicial ▁cooperation ▁is ▁being ▁in stitutionalised ▁or , ▁to ▁put ▁it ▁more ▁accurately , ▁that ▁there ▁is ▁a ▁trend ▁towards ▁ supranationalism ▁in ▁this ▁area .
#
# ==> Europarl.en-it.it-filtered.it.subword.dev <==
# ...

# %%
# Copy your data to your Google Drive
# !cp -R /content/nmt2/ /content/drive/MyDrive/NLP_Project/en_de/de_to_en
