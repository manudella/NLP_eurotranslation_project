# %%
# Create a directory and clone the Github MT-Preparation repository
# !mkdir -p nmt
# %cd nmt
# !git clone https://github.com/ymoslem/MT-Preparation.git
# Out:
# /content/nmt
# Cloning into 'MT-Preparation'...
# remote: Enumerating objects: 227, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 227 (delta 115), reused 186 (delta 94), pack-reused 0
# Receiving objects: 100% (227/227), 54.89 KiB | 13.72 MiB/s, done.
# Resolving deltas: 100% (115/115), done.

# %%
# Install the requirements
# !pip3 install -r MT-Preparation/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 49.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Download and unzip a dataset
# !unzip /content/drive/MyDrive/NLP_Project/it_es/es-it.txt.zip
# Out:
# Archive:  /content/drive/MyDrive/NLP_Project/it_es/es-it.txt.zip
#   inflating: README
#   inflating: LICENSE
#   inflating: Europarl.es-it.es
#   inflating: Europarl.es-it.it
#   inflating: Europarl.es-it.xml

# %%
# Filter the dataset
# Arguments: source file, target file, source language, target language
# !python3 MT-Preparation/filtering/filter.py Europarl.es-it.es Europarl.es-it.it es it
# Out:
# Dataframe shape (rows, columns): (1880982, 2)
# --- Rows with Empty Cells Deleted	--> Rows: 1880982
# --- Duplicates Deleted			--> Rows: 1843951
# --- Source-Copied Rows Deleted		--> Rows: 1843531
# --- Too Long Source/Target Deleted	--> Rows: 1826314
# --- HTML Removed			--> Rows: 1826314
# --- Rows will remain in true-cased	--> Rows: 1826314
# --- Rows with Empty Cells Deleted	--> Rows: 1826314
# --- Rows Shuffled			--> Rows: 1826314
# --- Source Saved: Europarl.es-it.es-filtered.es
# --- Target Saved: Europarl.es-it.it-filtered.it

# %%
# !ls MT-Preparation/subwording/
# Out:
# 1-train_bpe.py	1-train_unigram.py  2-subword.py  3-desubword.py

# %%
# Train a SentencePiece model for subword tokenization
# !python3 MT-Preparation/subwording/1-train_unigram.py Europarl.es-it.es-filtered.es Europarl.es-it.it-filtered.it
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=Europarl.es-it.es-filtered.es --model_prefix=source --vocab_size=50000 --hard_vocab_limit=false --split_digits=true
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: Europarl.es-it.es-filtered.es
#   input_format:
#   model_prefix: source
#   model_type: UNIGRAM
#   vocab_size: 50000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 1
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
# ...

# %%
# !ls
# Out:
# Europarl.es-it.es	       Europarl.es-it.xml  source.model
# Europarl.es-it.es-filtered.es  LICENSE		   source.vocab
# Europarl.es-it.it	       MT-Preparation	   target.model
# Europarl.es-it.it-filtered.it  README		   target.vocab

# %%
# Subword the dataset
# !python3 MT-Preparation/subwording/2-subword.py source.model target.model Europarl.es-it.es-filtered.es Europarl.es-it.it-filtered.it
# Out:
# Source Model: source.model
# Target Model: target.model
# Source Dataset: Europarl.es-it.es-filtered.es
# Target Dataset: Europarl.es-it.it-filtered.it
# Done subwording the source file! Output: Europarl.es-it.es-filtered.es.subword
# Done subwording the target file! Output: Europarl.es-it.it-filtered.it.subword

# %%
# First 3 lines before subwording
# !head -n 3 Europarl.es-it.es-filtered.es && echo "-----" && head -n 3 Europarl.es-it.it-filtered.it
# Out:
# Por lo que se refiere a la cuestión de una aplicación adecuada, en muchas ocasiones mi colega el señor McCreevy, ha llamado la atención de los Gobiernos de los Estados miembros sobre la importancia que tiene trabajar en la aplicación de la Directiva, y tanto él como su plantilla han seguido y controlado el proceso de aplicación muy de cerca.
# Señor Comisario Fischler, quien actúa así es que no ha negociado aún con ganado.
# Pero esto requiere algunos progresos en este ámbito.
# -----
# In merito alla questione della corretta attuazione, in diverse occasioni il mio collega, il commissario McCreevy, ha richiamato l'attenzione dei governi degli Stati membri sull'importanza del lavoro di attuazione e, assieme ai suoi collaboratori, ha seguito attentamente il relativo iter.
# Affermo a chiare lettere, Commissario Fischler, che chi si comporta in questo modo non ha mai avuto a che fare con il bestiame.
# ...

# %%
# First 3 lines after subwording
# !head -n 3 Europarl.es-it.es-filtered.es.subword && echo "---" && head -n 3 Europarl.es-it.it-filtered.it.subword
# Out:
# ▁Por ▁lo ▁que ▁se ▁refiere ▁a ▁la ▁cuestión ▁de ▁una ▁aplicación ▁adecuada , ▁en ▁muchas ▁ocasiones ▁mi ▁colega ▁el ▁señor ▁McCreevy , ▁ha ▁llamado ▁la ▁atención ▁de ▁los ▁Gobiernos ▁de ▁los ▁Estados ▁miembros ▁sobre ▁la ▁importancia ▁que ▁tiene ▁trabajar ▁en ▁la ▁aplicación ▁de ▁la ▁Directiva , ▁y ▁tanto ▁él ▁como ▁su ▁plantilla ▁han ▁seguido ▁y ▁controlado ▁el ▁proceso ▁de ▁aplicación ▁muy ▁de ▁cerca .
# ▁Señor ▁Comisario ▁Fischler , ▁quien ▁actúa ▁así ▁es ▁que ▁no ▁ha ▁negociado ▁aún ▁con ▁ganado .
# ▁Pero ▁esto ▁requiere ▁algunos ▁progresos ▁en ▁este ▁ámbito .
# ---
# ▁In ▁merito ▁alla ▁questione ▁della ▁corretta ▁attuazione , ▁in ▁diverse ▁occasioni ▁il ▁mio ▁collega , ▁il ▁commissario ▁McCreevy , ▁ha ▁richiamato ▁l ' attenzione ▁dei ▁governi ▁degli ▁Stati ▁membri ▁sull ' importanza ▁del ▁lavoro ▁di ▁attuazione ▁e , ▁assieme ▁ai ▁suoi ▁collaboratori , ▁ha ▁seguito ▁attentamente ▁il ▁relativo ▁iter .
# ...

# %%
# Split the dataset into training set, development set, and test set
# Development and test sets should be between 1000 and 5000 segments (here we chose 2000)
# !python3 MT-Preparation/train_dev_split/train_dev_test_split.py 4000 4000 Europarl.es-it.es-filtered.es.subword Europarl.es-it.it-filtered.it.subword
# Out:
# Dataframe shape: (1826314, 2)
# --- Empty Cells Deleted --> Rows: 1826314
# --- Wrote Files
# Done!
# Output files
# Europarl.es-it.es-filtered.es.subword.train
# Europarl.es-it.it-filtered.it.subword.train
# Europarl.es-it.es-filtered.es.subword.dev
# Europarl.es-it.it-filtered.it.subword.dev
# Europarl.es-it.es-filtered.es.subword.test
# Europarl.es-it.it-filtered.it.subword.test

# %%
# Line count for the subworded train, dev, test datatest
# !wc -l *.subword.*
# Out:
#      4000 Europarl.es-it.es-filtered.es.subword.dev
#      4000 Europarl.es-it.es-filtered.es.subword.test
#   1818314 Europarl.es-it.es-filtered.es.subword.train
#      4000 Europarl.es-it.it-filtered.it.subword.dev
#      4000 Europarl.es-it.it-filtered.it.subword.test
#   1818314 Europarl.es-it.it-filtered.it.subword.train
#   3652628 total

# %%
# Check the first and last line from each dataset

# -------------------------------------------
# Change this cell to print your name
# !echo -e "My name is: Manuel Piessalbo \n"
# -------------------------------------------

# !echo "---First line---"
# !head -n 1 *.{train,dev,test}

# !echo -e "\n---Last line---"
# !tail -n 1 *.{train,dev,test}
# Out:
# My name is: Manuel Piessalbo
#
# ---First line---
# ==> Europarl.es-it.es-filtered.es.subword.train <==
# ▁Por ▁lo ▁que ▁se ▁refiere ▁a ▁la ▁cuestión ▁de ▁una ▁aplicación ▁adecuada , ▁en ▁muchas ▁ocasiones ▁mi ▁colega ▁el ▁señor ▁McCreevy , ▁ha ▁llamado ▁la ▁atención ▁de ▁los ▁Gobiernos ▁de ▁los ▁Estados ▁miembros ▁sobre ▁la ▁importancia ▁que ▁tiene ▁trabajar ▁en ▁la ▁aplicación ▁de ▁la ▁Directiva , ▁y ▁tanto ▁él ▁como ▁su ▁plantilla ▁han ▁seguido ▁y ▁controlado ▁el ▁proceso ▁de ▁aplicación ▁muy ▁de ▁cerca .
#
# ==> Europarl.es-it.it-filtered.it.subword.train <==
# ▁In ▁merito ▁alla ▁questione ▁della ▁corretta ▁attuazione , ▁in ▁diverse ▁occasioni ▁il ▁mio ▁collega , ▁il ▁commissario ▁McCreevy , ▁ha ▁richiamato ▁l ' attenzione ▁dei ▁governi ▁degli ▁Stati ▁membri ▁sull ' importanza ▁del ▁lavoro ▁di ▁attuazione ▁e , ▁assieme ▁ai ▁suoi ▁collaboratori , ▁ha ▁seguito ▁attentamente ▁il ▁relativo ▁iter .
#
# ==> Europarl.es-it.es-filtered.es.subword.dev <==
# ...

# %%
# Copy your data to your Google Drive
# !cp -R /content/nmt/ /content/drive/MyDrive/NLP_Project/it_es/es_to_it
