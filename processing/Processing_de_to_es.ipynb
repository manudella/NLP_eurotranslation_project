# %%
# Create a directory and clone the Github MT-Preparation repository
# !mkdir -p nmt
# %cd nmt
# !git clone https://github.com/ymoslem/MT-Preparation.git
# Out:
# /content/nmt
# Cloning into 'MT-Preparation'...
# remote: Enumerating objects: 227, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 227 (delta 115), reused 186 (delta 94), pack-reused 0
# Receiving objects: 100% (227/227), 54.89 KiB | 1.19 MiB/s, done.
# Resolving deltas: 100% (115/115), done.

# %%
# Install the requirements
# !pip3 install -r MT-Preparation/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Download and unzip a dataset
# !unzip /content/drive/MyDrive/NLP_Project/es_de/de-es.txt.zip
# Out:
# Archive:  /content/drive/MyDrive/NLP_Project/es_de/de-es.txt.zip
#   inflating: README
#   inflating: LICENSE
#   inflating: Europarl.de-es.de
#   inflating: Europarl.de-es.es
#   inflating: Europarl.de-es.xml

# %%
# Filter the dataset
# Arguments: source file, target file, source language, target language
# !python3 MT-Preparation/filtering/filter.py Europarl.de-es.de Europarl.de-es.es de es
# Out:
# Dataframe shape (rows, columns): (1887879, 2)
# --- Rows with Empty Cells Deleted	--> Rows: 1887879
# --- Duplicates Deleted			--> Rows: 1848294
# --- Source-Copied Rows Deleted		--> Rows: 1847970
# --- Too Long Source/Target Deleted	--> Rows: 1828788
# --- HTML Removed			--> Rows: 1828788
# --- Rows will remain in true-cased	--> Rows: 1828788
# --- Rows with Empty Cells Deleted	--> Rows: 1828788
# --- Rows Shuffled			--> Rows: 1828788
# --- Source Saved: Europarl.de-es.de-filtered.de
# --- Target Saved: Europarl.de-es.es-filtered.es

# %%
# !ls MT-Preparation/subwording/
# Out:
# 1-train_bpe.py	1-train_unigram.py  2-subword.py  3-desubword.py

# %%
# Train a SentencePiece model for subword tokenization
# !python3 MT-Preparation/subwording/1-train_unigram.py Europarl.de-es.de-filtered.de Europarl.de-es.es-filtered.es
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=Europarl.de-es.de-filtered.de --model_prefix=source --vocab_size=50000 --hard_vocab_limit=false --split_digits=true
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: Europarl.de-es.de-filtered.de
#   input_format:
#   model_prefix: source
#   model_type: UNIGRAM
#   vocab_size: 50000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 1
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
# ...

# %%
# !ls
# Out:
# Europarl.de-es.de	       Europarl.de-es.xml  source.model
# Europarl.de-es.de-filtered.de  LICENSE		   source.vocab
# Europarl.de-es.es	       MT-Preparation	   target.model
# Europarl.de-es.es-filtered.es  README		   target.vocab

# %%
# Subword the dataset
# !python3 MT-Preparation/subwording/2-subword.py source.model target.model Europarl.de-es.de-filtered.de Europarl.de-es.es-filtered.es
# Out:
# Source Model: source.model
# Target Model: target.model
# Source Dataset: Europarl.de-es.de-filtered.de
# Target Dataset: Europarl.de-es.es-filtered.es
# Done subwording the source file! Output: Europarl.de-es.de-filtered.de.subword
# Done subwording the target file! Output: Europarl.de-es.es-filtered.es.subword

# %%
# First 3 lines before subwording
# !head -n 3 Europarl.de-es.es-filtered.es && echo "-----" && head -n 3 Europarl.de-es.de-filtered.de
# Out:
# La UE ha planteado sistemáticamente en todos los niveles el asunto concreto del artículo 301 del Código Penal turco y de otros artículos redactados de modo impreciso en el marco del proceso de reformas en curso en Turquía.
# Respecto a la cantidad de los fondos, si se facilitaran más fondos, la Comisión sin duda no se quejaría.
# Por tanto, nuestra acción universal en este sentido es muy importante.
# -----
# Die spezielle Frage des Artikels 301 des türkischen Strafgesetzbuches sowie anderer Artikel, die vage Formulierungen enthalten, ist von der EU auf allen Ebenen im Rahmen des laufenden Reformprozesses in der Türkei systematisch zur Sprache gebracht worden.
# Was den Umfang der Mittel betrifft, so würde sich die Kommission durchaus nicht beschweren, ständen mehr davon zur Verfügung.
# Deshalb ist unser weltweites Handeln in diese Richtung von großer Bedeutung.

# %%
# First 3 lines after subwording
# !head -n 3 Europarl.de-es.es-filtered.es.subword && echo "---" && head -n 3 Europarl.de-es.de-filtered.de.subword
# Out:
# ▁La ▁UE ▁ha ▁planteado ▁ sistemáticamente ▁en ▁todos ▁los ▁niveles ▁el ▁asunto ▁concreto ▁del ▁artículo ▁ 3 0 1 ▁del ▁Código ▁Penal ▁turco ▁y ▁de ▁otros ▁artículos ▁redactados ▁de ▁modo ▁impreciso ▁en ▁el ▁marco ▁del ▁proceso ▁de ▁reformas ▁en ▁curso ▁en ▁Turquía .
# ▁Respect o ▁a ▁la ▁cantidad ▁de ▁los ▁fondos , ▁si ▁se ▁facilitaran ▁más ▁fondos , ▁la ▁Comisión ▁sin ▁duda ▁no ▁se ▁queja ría .
# ▁Por ▁tanto , ▁nuestra ▁acción ▁universal ▁en ▁este ▁sentido ▁es ▁muy ▁importante .
# ---
# ▁Die ▁spezielle ▁Frage ▁des ▁Artikels ▁ 3 0 1 ▁des ▁türkischen ▁Strafgesetzbuch es ▁sowie ▁anderer ▁Artikel , ▁die ▁vage ▁Formulierungen ▁enthalten , ▁ist ▁von ▁der ▁EU ▁auf ▁allen ▁Ebenen ▁im ▁Rahmen ▁des ▁laufenden ▁Reformprozesses ▁in ▁der ▁Türkei ▁systematisch ▁zur ▁Sprache ▁gebracht ▁worden .
# ▁Was ▁den ▁Umfang ▁der ▁Mittel ▁betrifft , ▁so ▁würde ▁sich ▁die ▁Kommission ▁durchaus ▁nicht ▁beschweren , ▁ ständen ▁mehr ▁davon ▁zur ▁Verfügung .
# ...

# %%
# Split the dataset into training set, development set, and test set
# Development and test sets should be between 1000 and 5000 segments (here we chose 2000)
# !python3 MT-Preparation/train_dev_split/train_dev_test_split.py 4000 4000 Europarl.de-es.de-filtered.de.subword Europarl.de-es.es-filtered.es.subword
# Out:
# Dataframe shape: (1828788, 2)
# --- Empty Cells Deleted --> Rows: 1828788
# --- Wrote Files
# Done!
# Output files
# Europarl.de-es.de-filtered.de.subword.train
# Europarl.de-es.es-filtered.es.subword.train
# Europarl.de-es.de-filtered.de.subword.dev
# Europarl.de-es.es-filtered.es.subword.dev
# Europarl.de-es.de-filtered.de.subword.test
# Europarl.de-es.es-filtered.es.subword.test

# %%
# Line count for the subworded train, dev, test datatest
# !wc -l *.subword.*
# Out:
#      4000 Europarl.de-es.de-filtered.de.subword.dev
#      4000 Europarl.de-es.de-filtered.de.subword.test
#   1820788 Europarl.de-es.de-filtered.de.subword.train
#      4000 Europarl.de-es.es-filtered.es.subword.dev
#      4000 Europarl.de-es.es-filtered.es.subword.test
#   1820788 Europarl.de-es.es-filtered.es.subword.train
#   3657576 total

# %%
# Check the first and last line from each dataset

# -------------------------------------------
# Change this cell to print your name
# !echo -e "My name is: Manuel Piessalbo \n"
# -------------------------------------------

# !echo "---First line---"
# !head -n 1 *.{train,dev,test}

# !echo -e "\n---Last line---"
# !tail -n 1 *.{train,dev,test}
# Out:
# My name is: Manuel Piessalbo
#
# ---First line---
# ==> Europarl.de-es.de-filtered.de.subword.train <==
# ▁Die ▁spezielle ▁Frage ▁des ▁Artikels ▁ 3 0 1 ▁des ▁türkischen ▁Strafgesetzbuch es ▁sowie ▁anderer ▁Artikel , ▁die ▁vage ▁Formulierungen ▁enthalten , ▁ist ▁von ▁der ▁EU ▁auf ▁allen ▁Ebenen ▁im ▁Rahmen ▁des ▁laufenden ▁Reformprozesses ▁in ▁der ▁Türkei ▁systematisch ▁zur ▁Sprache ▁gebracht ▁worden .
#
# ==> Europarl.de-es.es-filtered.es.subword.train <==
# ▁La ▁UE ▁ha ▁planteado ▁ sistemáticamente ▁en ▁todos ▁los ▁niveles ▁el ▁asunto ▁concreto ▁del ▁artículo ▁ 3 0 1 ▁del ▁Código ▁Penal ▁turco ▁y ▁de ▁otros ▁artículos ▁redactados ▁de ▁modo ▁impreciso ▁en ▁el ▁marco ▁del ▁proceso ▁de ▁reformas ▁en ▁curso ▁en ▁Turquía .
#
# ==> Europarl.de-es.de-filtered.de.subword.dev <==
# ...

# %%
# Copy your data to your Google Drive
# !cp -R /content/nmt/ /content/drive/MyDrive/NLP_Project/es_de/de_to_es
