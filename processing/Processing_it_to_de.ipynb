# %%
# Create a directory and clone the Github MT-Preparation repository
# !mkdir -p nmt
# %cd nmt
# !git clone https://github.com/ymoslem/MT-Preparation.git
# Out:
# /content/nmt
# Cloning into 'MT-Preparation'...
# remote: Enumerating objects: 227, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 227 (delta 115), reused 186 (delta 94), pack-reused 0
# Receiving objects: 100% (227/227), 54.89 KiB | 1.96 MiB/s, done.
# Resolving deltas: 100% (115/115), done.

# %%
# Install the requirements
# !pip3 install -r MT-Preparation/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r MT-Preparation/requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r MT-Preparation/requirements.txt (line 2)) (1.5.3)
# Collecting sentencepiece (from -r MT-Preparation/requirements.txt (line 3))
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r MT-Preparation/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r MT-Preparation/requirements.txt (line 2)) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->-r MT-Preparation/requirements.txt (line 2)) (1.16.0)
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Download and unzip a dataset
# !unzip /content/drive/MyDrive/NLP_Project/it_de/de-it.txt.zip
# Out:
# Archive:  /content/drive/MyDrive/NLP_Project/it_de/de-it.txt.zip
#   inflating: README
#   inflating: LICENSE
#   inflating: Europarl.de-it.de
#   inflating: Europarl.de-it.it
#   inflating: Europarl.de-it.xml

# %%
# Filter the dataset
# Arguments: source file, target file, source language, target language
# !python3 MT-Preparation/filtering/filter.py Europarl.de-it.it Europarl.de-it.de it de
# Out:
# Dataframe shape (rows, columns): (1832989, 2)
# --- Rows with Empty Cells Deleted	--> Rows: 1832989
# --- Duplicates Deleted			--> Rows: 1800264
# --- Source-Copied Rows Deleted		--> Rows: 1799893
# --- Too Long Source/Target Deleted	--> Rows: 1777029
# --- HTML Removed			--> Rows: 1777029
# --- Rows will remain in true-cased	--> Rows: 1777029
# --- Rows with Empty Cells Deleted	--> Rows: 1777029
# --- Rows Shuffled			--> Rows: 1777029
# --- Source Saved: Europarl.de-it.it-filtered.it
# --- Target Saved: Europarl.de-it.de-filtered.de

# %%
# !ls MT-Preparation/subwording/
# Out:
# 1-train_bpe.py	1-train_unigram.py  2-subword.py  3-desubword.py

# %%
# Train a SentencePiece model for subword tokenization
# !python3 MT-Preparation/subwording/1-train_unigram.py Europarl.de-it.it-filtered.it Europarl.de-it.de-filtered.de
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=Europarl.de-it.it-filtered.it --model_prefix=source --vocab_size=50000 --hard_vocab_limit=false --split_digits=true
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: Europarl.de-it.it-filtered.it
#   input_format:
#   model_prefix: source
#   model_type: UNIGRAM
#   vocab_size: 50000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 1
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 0
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(351) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(183) LOG(INFO) Loading corpus: Europarl.de-it.it-filtered.it
# trainer_interface.cc(145) LOG(INFO) Loaded 1000000 lines
# trainer_interface.cc(122) LOG(WARNING) Too many sentences are loaded! (1777029), which may slow down training.
# trainer_interface.cc(124) LOG(WARNING) Consider using --input_sentence_size=<size> and --shuffle_input_sentence=true.
# trainer_interface.cc(127) LOG(WARNING) They allow to randomly sample <size> sentences from the entire corpus.
# trainer_interface.cc(407) LOG(INFO) Loaded all 1777029 sentences
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(428) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(537) LOG(INFO) all chars count=306660452
# trainer_interface.cc(548) LOG(INFO) Done: 99.9523% characters are covered.
# trainer_interface.cc(558) LOG(INFO) Alphabet size=77
# trainer_interface.cc(559) LOG(INFO) Final character coverage=0.999523
# trainer_interface.cc(591) LOG(INFO) Done! preprocessed 1777029 sentences.
# unigram_model_trainer.cc(222) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(226) LOG(INFO) Extracting frequent sub strings... node_num=170225204
# unigram_model_trainer.cc(274) LOG(INFO) Initialized 493226 seed sentencepieces
# trainer_interface.cc(597) LOG(INFO) Tokenizing input sentences with whitespace: 1777029
# trainer_interface.cc(608) LOG(INFO) Done! 438949
# unigram_model_trainer.cc(564) LOG(INFO) Using 438949 sentences for EM training
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=164269 obj=11.5422 num_tokens=1224025 num_tokens/piece=7.45135
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=127496 obj=8.56137 num_tokens=1223588 num_tokens/piece=9.59707
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=95620 obj=8.52267 num_tokens=1257774 num_tokens/piece=13.1539
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=95569 obj=8.51965 num_tokens=1257786 num_tokens/piece=13.161
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=71676 obj=8.53244 num_tokens=1319398 num_tokens/piece=18.4078
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=71674 obj=8.53234 num_tokens=1319325 num_tokens/piece=18.4073
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=55000 obj=8.55263 num_tokens=1386064 num_tokens/piece=25.2012
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=55000 obj=8.5486 num_tokens=1386003 num_tokens/piece=25.2001
# trainer_interface.cc(686) LOG(INFO) Saving model: source.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: source.vocab
# Done, training a SentencepPiece model for the Source finished successfully!
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=Europarl.de-it.de-filtered.de --model_prefix=target --vocab_size=50000 --hard_vocab_limit=false --split_digits=true
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: Europarl.de-it.de-filtered.de
#   input_format:
#   model_prefix: target
#   model_type: UNIGRAM
#   vocab_size: 50000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 1
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 0
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(351) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(183) LOG(INFO) Loading corpus: Europarl.de-it.de-filtered.de
# trainer_interface.cc(145) LOG(INFO) Loaded 1000000 lines
# trainer_interface.cc(122) LOG(WARNING) Too many sentences are loaded! (1777029), which may slow down training.
# trainer_interface.cc(124) LOG(WARNING) Consider using --input_sentence_size=<size> and --shuffle_input_sentence=true.
# trainer_interface.cc(127) LOG(WARNING) They allow to randomly sample <size> sentences from the entire corpus.
# trainer_interface.cc(407) LOG(INFO) Loaded all 1777029 sentences
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(428) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(537) LOG(INFO) all chars count=318920177
# trainer_interface.cc(548) LOG(INFO) Done: 99.9572% characters are covered.
# trainer_interface.cc(558) LOG(INFO) Alphabet size=78
# trainer_interface.cc(559) LOG(INFO) Final character coverage=0.999572
# trainer_interface.cc(591) LOG(INFO) Done! preprocessed 1777029 sentences.
# unigram_model_trainer.cc(222) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(226) LOG(INFO) Extracting frequent sub strings... node_num=168577611
# unigram_model_trainer.cc(274) LOG(INFO) Initialized 1000078 seed sentencepieces
# trainer_interface.cc(597) LOG(INFO) Tokenizing input sentences with whitespace: 1777029
# trainer_interface.cc(608) LOG(INFO) Done! 628840
# unigram_model_trainer.cc(564) LOG(INFO) Using 628840 sentences for EM training
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=251355 obj=11.7198 num_tokens=1637982 num_tokens/piece=6.51661
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=183325 obj=8.65352 num_tokens=1642856 num_tokens/piece=8.96144
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=137337 obj=8.61684 num_tokens=1680655 num_tokens/piece=12.2375
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=137083 obj=8.60993 num_tokens=1682024 num_tokens/piece=12.2701
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=102790 obj=8.62625 num_tokens=1754644 num_tokens/piece=17.0702
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=102779 obj=8.62327 num_tokens=1754868 num_tokens/piece=17.0742
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=77076 obj=8.651 num_tokens=1840599 num_tokens/piece=23.8803
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=77072 obj=8.64871 num_tokens=1840558 num_tokens/piece=23.881
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=57801 obj=8.6896 num_tokens=1937917 num_tokens/piece=33.5274
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=57798 obj=8.68679 num_tokens=1937900 num_tokens/piece=33.5288
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=54999 obj=8.68867 num_tokens=1953775 num_tokens/piece=35.5238
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=54999 obj=8.68905 num_tokens=1953774 num_tokens/piece=35.5238
# trainer_interface.cc(686) LOG(INFO) Saving model: target.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: target.vocab
# Done, training a SentencepPiece model for the Target finished successfully!

# %%
# !ls
# Out:
# Europarl.de-it.de	       Europarl.de-it.xml  source.model
# Europarl.de-it.de-filtered.de  LICENSE		   source.vocab
# Europarl.de-it.it	       MT-Preparation	   target.model
# Europarl.de-it.it-filtered.it  README		   target.vocab

# %%
# Subword the dataset
# !python3 MT-Preparation/subwording/2-subword.py source.model target.model Europarl.de-it.it-filtered.it Europarl.de-it.de-filtered.de
# Out:
# Source Model: source.model
# Target Model: target.model
# Source Dataset: Europarl.de-it.it-filtered.it
# Target Dataset: Europarl.de-it.de-filtered.de
# Done subwording the source file! Output: Europarl.de-it.it-filtered.it.subword
# Done subwording the target file! Output: Europarl.de-it.de-filtered.de.subword

# %%
# First 3 lines before subwording
# !head -n 3 Europarl.de-it.de-filtered.de && echo "-----" && head -n 3 Europarl.de-it.it-filtered.it
# Out:
# Nicht zuletzt wollten wir der außenpolitischen Agenda der Europäischen Union erneut Kohärenz und Dynamik verleihen.
# Das wäre fast wie die Warnhinweise, wie man sie auf Zigarettenpackungen findet.
# Ich werde also gegen diese beiden Änderungsanträge stimmen.
# -----
# Ultimo punto, ma assolutamente non meno importante, abbiamo cercato di dare rinnovata coerenza e nuovo slancio all’agenda esterna dell’Unione europea.
# Ricorderebbe quasi una di quelle avvertenze riportate sui pacchetti di sigarette.
# Voterò pertanto contro questi due emendamenti.

# %%
# First 3 lines after subwording
# !head -n 3 Europarl.de-it.de-filtered.de.subword && echo "---" && head -n 3 Europarl.de-it.it-filtered.it.subword
# Out:
# ▁Nicht ▁zuletzt ▁wollten ▁wir ▁der ▁ außenpolitischen ▁Agenda ▁der ▁ Europäischen ▁Union ▁erneut ▁Kohärenz ▁und ▁Dynamik ▁verleihen .
# ▁Das ▁wäre ▁fast ▁wie ▁die ▁Warnhinweise , ▁wie ▁man ▁sie ▁auf ▁Zigaretten packungen ▁findet .
# ▁Ich ▁werde ▁also ▁gegen ▁diese ▁beiden ▁ Änderungsanträge ▁stimmen .
# ---
# ▁Ultimo ▁punto , ▁ma ▁assolutamente ▁non ▁meno ▁importante , ▁abbiamo ▁cercato ▁di ▁dare ▁rinnovata ▁coerenza ▁e ▁nuovo ▁slancio ▁all ’ agenda ▁esterna ▁dell ’ Unione ▁europea .
# ▁Ricordere bbe ▁quasi ▁una ▁di ▁quelle ▁avvertenze ▁riportate ▁sui ▁pacchetti ▁di ▁sigarette .
# ▁Voterò ▁pertanto ▁contro ▁questi ▁due ▁emendamenti .

# %%
# Split the dataset into training set, development set, and test set
# Development and test sets should be between 1000 and 5000 segments (here we chose 2000)
# !python3 MT-Preparation/train_dev_split/train_dev_test_split.py 4000 4000 Europarl.de-it.it-filtered.it.subword Europarl.de-it.de-filtered.de.subword
# Out:
# Dataframe shape: (1777029, 2)
# --- Empty Cells Deleted --> Rows: 1777029
# --- Wrote Files
# Done!
# Output files
# Europarl.de-it.it-filtered.it.subword.train
# Europarl.de-it.de-filtered.de.subword.train
# Europarl.de-it.it-filtered.it.subword.dev
# Europarl.de-it.de-filtered.de.subword.dev
# Europarl.de-it.it-filtered.it.subword.test
# Europarl.de-it.de-filtered.de.subword.test

# %%
# Line count for the subworded train, dev, test datatest
# !wc -l *.subword.*
# Out:
#      4000 Europarl.de-it.de-filtered.de.subword.dev
#      4000 Europarl.de-it.de-filtered.de.subword.test
#   1769029 Europarl.de-it.de-filtered.de.subword.train
#      4000 Europarl.de-it.it-filtered.it.subword.dev
#      4000 Europarl.de-it.it-filtered.it.subword.test
#   1769029 Europarl.de-it.it-filtered.it.subword.train
#   3554058 total

# %%
# Check the first and last line from each dataset

# -------------------------------------------
# Change this cell to print your name
# !echo -e "My name is: Manuel Piessalbo \n"
# -------------------------------------------

# !echo "---First line---"
# !head -n 1 *.{train,dev,test}

# !echo -e "\n---Last line---"
# !tail -n 1 *.{train,dev,test}
# Out:
# My name is: Manuel Piessalbo
#
# ---First line---
# ==> Europarl.de-it.de-filtered.de.subword.train <==
# ▁Nicht ▁zuletzt ▁wollten ▁wir ▁der ▁ außenpolitischen ▁Agenda ▁der ▁ Europäischen ▁Union ▁erneut ▁Kohärenz ▁und ▁Dynamik ▁verleihen .
#
# ==> Europarl.de-it.it-filtered.it.subword.train <==
# ▁Ultimo ▁punto , ▁ma ▁assolutamente ▁non ▁meno ▁importante , ▁abbiamo ▁cercato ▁di ▁dare ▁rinnovata ▁coerenza ▁e ▁nuovo ▁slancio ▁all ’ agenda ▁esterna ▁dell ’ Unione ▁europea .
#
# ==> Europarl.de-it.de-filtered.de.subword.dev <==
# ▁Wir ▁werden ▁nicht ▁dulden , ▁daß ▁er ▁unsere ▁ehrenwerte n ▁Polizisten ▁beleidigt , ▁die ▁ihr ▁Leben ▁gelassen ▁haben ▁oder ▁bleiben de ▁Verletzungen ▁davongetragen ▁haben .
#
# ==> Europarl.de-it.it-filtered.it.subword.dev <==
# ▁Non ▁possiamo ▁tollerare ▁il ▁suo ▁insulto ▁ai ▁nostri ▁poliziotti ▁caduti ▁e ▁feriti .
#
# ==> Europarl.de-it.de-filtered.de.subword.test <==
# ▁Daher ▁bevorzugen ▁wir ▁noch ▁immer , ▁wie ▁ich ▁bereits ▁ausführte , ▁einen ▁gemeinsamen ▁Ansatz ▁mit ▁den ▁ASEAN - Ländern .
#
# ==> Europarl.de-it.it-filtered.it.subword.test <==
# ▁Pertanto , ▁onorevole ▁Mann , ▁per ▁le ▁ragioni ▁che ▁ho ▁appena ▁indicato ▁la ▁nostra ▁preferenza ▁va ▁sempre ▁a ▁un ▁approccio ▁comune ▁con ▁i ▁paesi ▁ASEAN .
#
# ---Last line---
# ==> Europarl.de-it.de-filtered.de.subword.train <==
# ▁Nur ▁so ▁wird ▁verhindert , ▁dass ▁dieser ▁Fonds ▁zu ▁einer ▁Alibi funktion ▁wird .
#
# ==> Europarl.de-it.it-filtered.it.subword.train <==
# ▁Solo ▁così ▁si ▁impedisce ▁che ▁il ▁Fondo ▁diventi ▁un ▁mero ▁gesto ▁simbolico .
#
# ==> Europarl.de-it.de-filtered.de.subword.dev <==
# ▁Der ▁Glaube , ▁ein ▁makroökonomisch er ▁Dialog ▁könne ▁ernsthaft ▁geführt ▁werden , ▁wenn ▁einige ▁Mitgliedstaaten ▁der ▁EWU ▁fern bleiben , ▁während ▁der ▁größte ▁Teil ▁der ▁Länder ▁beitritt , ▁ist ▁meiner ▁Meinung ▁nach ▁eine ▁Illusion . ▁Auf ▁Dauer ▁wird ▁das ▁nicht ▁funktionieren .
#
# ==> Europarl.de-it.it-filtered.it.subword.dev <==
# ▁Crede re ▁che ▁sia ▁possibile ▁un ▁serio ▁dialogo ▁macroeconomico ▁quando ▁alcuni ▁Stati ▁membri ▁restano ▁fuori ▁dall ' ▁UEM , ▁mentre ▁quasi ▁tutti ▁gli ▁altri ▁vi ▁partecipano , ▁è ▁a ▁mio ▁avviso ▁un ' ▁illusione ▁destinata ▁a ▁durare ▁ben ▁poco .
#
# ==> Europarl.de-it.de-filtered.de.subword.test <==
# ▁Wenn ▁hierin ▁für ▁die ▁ Christdemokraten ▁das ▁eigentliche ▁Problem ▁liegt , ▁dann ▁müssen ▁sie ▁das ▁sagen .
#
# ==> Europarl.de-it.it-filtered.it.subword.test <==
# ▁Se ▁il ▁vero ▁problema ▁dei ▁democratici ▁cristiani ▁è ▁questo , ▁essi ▁dovrebbero ▁dirlo .

# %%
# Copy your data to your Google Drive
# !cp -R /content/nmt/ /content/drive/MyDrive/NLP_Project/it_de/it_to_de
