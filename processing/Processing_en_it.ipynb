# %%
# Create a directory and clone the Github MT-Preparation repository
# !mkdir -p nmt2
# %cd nmt2
# !git clone https://github.com/ymoslem/MT-Preparation.git
# Out:
# /content/nmt2
# Cloning into 'MT-Preparation'...
# remote: Enumerating objects: 227, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 227 (delta 115), reused 186 (delta 94), pack-reused 0
# Receiving objects: 100% (227/227), 54.89 KiB | 13.72 MiB/s, done.
# Resolving deltas: 100% (115/115), done.

# %%
# Install the requirements
# !pip3 install -r MT-Preparation/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r MT-Preparation/requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r MT-Preparation/requirements.txt (line 2)) (1.5.3)
# Collecting sentencepiece (from -r MT-Preparation/requirements.txt (line 3))
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r MT-Preparation/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r MT-Preparation/requirements.txt (line 2)) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->-r MT-Preparation/requirements.txt (line 2)) (1.16.0)
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Download and unzip a dataset
# !unzip /content/drive/MyDrive/NLP_Project/en_it/en-it.txt.zip
# Out:
# Archive:  /content/drive/MyDrive/NLP_Project/en_it/en-it.txt.zip
#   inflating: README
#   inflating: LICENSE
#   inflating: Europarl.en-it.en
#   inflating: Europarl.en-it.it
#   inflating: Europarl.en-it.xml

# %%
# Filter the dataset
# Arguments: source file, target file, source language, target language
# !python3 MT-Preparation/filtering/filter.py Europarl.en-it.it Europarl.en-it.en it en
# Out:
# Dataframe shape (rows, columns): (1946253, 2)
# --- Rows with Empty Cells Deleted	--> Rows: 1946253
# --- Duplicates Deleted			--> Rows: 1907207
# --- Source-Copied Rows Deleted		--> Rows: 1906715
# --- Too Long Source/Target Deleted	--> Rows: 1889521
# --- HTML Removed			--> Rows: 1889521
# --- Rows will remain in true-cased	--> Rows: 1889521
# --- Rows with Empty Cells Deleted	--> Rows: 1889521
# --- Rows Shuffled			--> Rows: 1889521
# --- Source Saved: Europarl.en-it.it-filtered.it
# --- Target Saved: Europarl.en-it.en-filtered.en

# %%
# !ls MT-Preparation/subwording/
# Out:
# 1-train_bpe.py	1-train_unigram.py  2-subword.py  3-desubword.py

# %%
# Train a SentencePiece model for subword tokenization
# !python3 MT-Preparation/subwording/1-train_unigram.py Europarl.en-it.it-filtered.it Europarl.en-it.en-filtered.en
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=Europarl.en-it.it-filtered.it --model_prefix=source --vocab_size=50000 --hard_vocab_limit=false --split_digits=true
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: Europarl.en-it.it-filtered.it
#   input_format:
#   model_prefix: source
#   model_type: UNIGRAM
#   vocab_size: 50000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 1
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 0
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(351) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(183) LOG(INFO) Loading corpus: Europarl.en-it.it-filtered.it
# trainer_interface.cc(145) LOG(INFO) Loaded 1000000 lines
# trainer_interface.cc(122) LOG(WARNING) Too many sentences are loaded! (1889521), which may slow down training.
# trainer_interface.cc(124) LOG(WARNING) Consider using --input_sentence_size=<size> and --shuffle_input_sentence=true.
# trainer_interface.cc(127) LOG(WARNING) They allow to randomly sample <size> sentences from the entire corpus.
# trainer_interface.cc(407) LOG(INFO) Loaded all 1889521 sentences
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(428) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(537) LOG(INFO) all chars count=326061494
# trainer_interface.cc(548) LOG(INFO) Done: 99.9525% characters are covered.
# trainer_interface.cc(558) LOG(INFO) Alphabet size=77
# trainer_interface.cc(559) LOG(INFO) Final character coverage=0.999525
# trainer_interface.cc(591) LOG(INFO) Done! preprocessed 1889521 sentences.
# unigram_model_trainer.cc(222) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(226) LOG(INFO) Extracting frequent sub strings... node_num=181043841
# unigram_model_trainer.cc(274) LOG(INFO) Initialized 503379 seed sentencepieces
# trainer_interface.cc(597) LOG(INFO) Tokenizing input sentences with whitespace: 1889521
# trainer_interface.cc(608) LOG(INFO) Done! 451917
# unigram_model_trainer.cc(564) LOG(INFO) Using 451917 sentences for EM training
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=168046 obj=11.5439 num_tokens=1266204 num_tokens/piece=7.53487
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=130375 obj=8.56034 num_tokens=1262732 num_tokens/piece=9.68538
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=97777 obj=8.52152 num_tokens=1297764 num_tokens/piece=13.2727
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=97728 obj=8.51778 num_tokens=1297793 num_tokens/piece=13.2796
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=73296 obj=8.53067 num_tokens=1360402 num_tokens/piece=18.5604
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=73294 obj=8.53095 num_tokens=1360333 num_tokens/piece=18.56
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=55000 obj=8.55325 num_tokens=1435477 num_tokens/piece=26.0996
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=55000 obj=8.54885 num_tokens=1435449 num_tokens/piece=26.0991
# trainer_interface.cc(686) LOG(INFO) Saving model: source.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: source.vocab
# Done, training a SentencepPiece model for the Source finished successfully!
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=Europarl.en-it.en-filtered.en --model_prefix=target --vocab_size=50000 --hard_vocab_limit=false --split_digits=true
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: Europarl.en-it.en-filtered.en
#   input_format:
#   model_prefix: target
#   model_type: UNIGRAM
#   vocab_size: 50000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 1
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 0
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(351) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(183) LOG(INFO) Loading corpus: Europarl.en-it.en-filtered.en
# trainer_interface.cc(145) LOG(INFO) Loaded 1000000 lines
# trainer_interface.cc(122) LOG(WARNING) Too many sentences are loaded! (1889521), which may slow down training.
# trainer_interface.cc(124) LOG(WARNING) Consider using --input_sentence_size=<size> and --shuffle_input_sentence=true.
# trainer_interface.cc(127) LOG(WARNING) They allow to randomly sample <size> sentences from the entire corpus.
# trainer_interface.cc(407) LOG(INFO) Loaded all 1889521 sentences
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(428) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(537) LOG(INFO) all chars count=300991937
# trainer_interface.cc(548) LOG(INFO) Done: 99.9506% characters are covered.
# trainer_interface.cc(558) LOG(INFO) Alphabet size=71
# trainer_interface.cc(559) LOG(INFO) Final character coverage=0.999506
# trainer_interface.cc(591) LOG(INFO) Done! preprocessed 1889521 sentences.
# unigram_model_trainer.cc(222) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(226) LOG(INFO) Extracting frequent sub strings... node_num=161407425
# unigram_model_trainer.cc(274) LOG(INFO) Initialized 269710 seed sentencepieces
# trainer_interface.cc(597) LOG(INFO) Tokenizing input sentences with whitespace: 1889521
# trainer_interface.cc(608) LOG(INFO) Done! 297820
# unigram_model_trainer.cc(564) LOG(INFO) Using 297820 sentences for EM training
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=104084 obj=10.2588 num_tokens=909983 num_tokens/piece=8.74278
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=81436 obj=7.6252 num_tokens=913198 num_tokens/piece=11.2137
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=61076 obj=7.58828 num_tokens=943218 num_tokens/piece=15.4433
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=61064 obj=7.58613 num_tokens=944548 num_tokens/piece=15.4682
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=55000 obj=7.58684 num_tokens=960377 num_tokens/piece=17.4614
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=55000 obj=7.5868 num_tokens=960362 num_tokens/piece=17.4611
# trainer_interface.cc(686) LOG(INFO) Saving model: target.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: target.vocab
# Done, training a SentencepPiece model for the Target finished successfully!

# %%
# !ls
# Out:
# Europarl.en-it.en	       Europarl.en-it.xml  source.model
# Europarl.en-it.en-filtered.en  LICENSE		   source.vocab
# Europarl.en-it.it	       MT-Preparation	   target.model
# Europarl.en-it.it-filtered.it  README		   target.vocab

# %%
# Subword the dataset
# !python3 MT-Preparation/subwording/2-subword.py source.model target.model Europarl.en-it.it-filtered.it Europarl.en-it.en-filtered.en
# Out:
# Source Model: source.model
# Target Model: target.model
# Source Dataset: Europarl.en-it.it-filtered.it
# Target Dataset: Europarl.en-it.en-filtered.en
# Done subwording the source file! Output: Europarl.en-it.it-filtered.it.subword
# Done subwording the target file! Output: Europarl.en-it.en-filtered.en.subword

# %%
# First 3 lines before subwording
# !head -n 3 Europarl.en-it.en-filtered.en && echo "-----" && head -n 3 Europarl.en-it.it-filtered.it
# Out:
# Despite that selective approach, it is good that crimes should be punished, even if an attempt is made to justify them in terms of the exigencies of war.
# (IT) I have received a request from Mr Hannan for an item on the interpretation of Rule 19 of our Rules of Procedure.
# The support of the British Conservatives once again clearly shows the untenable association of this group with the European People’s Party tradition, so well represented by Mrs Grossetête and also by Mrs Avilés Perea.
# -----
# Nonostante questo approccio selettivo, è positivo che i crimini vengano puniti, anche se si tenta di giustificarli in termini di esigenze di guerra.
# Ho ricevuto una richiesta dall'onorevole Hannan per un punto riguardante l'interpretazione dell'articolo 19 del nostro regolamento.
# L’adesione dei conservatori britannici rende ancora una volta evidente l’insostenibile convivenza di questo gruppo con la tradizione popolare europea, così ben rappresentata dalla collega Grossetête e anche dalla collega Avilés Perea.

# %%
# First 3 lines after subwording
# !head -n 3 Europarl.en-it.en-filtered.en.subword && echo "---" && head -n 3 Europarl.en-it.it-filtered.it.subword
# Out:
# ▁Despite ▁that ▁selective ▁approach , ▁it ▁is ▁good ▁that ▁crimes ▁should ▁be ▁punished , ▁even ▁if ▁an ▁attempt ▁is ▁made ▁to ▁justify ▁them ▁in ▁terms ▁of ▁the ▁exigencies ▁of ▁war .
# ▁( IT ) ▁I ▁have ▁received ▁a ▁request ▁from ▁Mr ▁Hannan ▁for ▁an ▁item ▁on ▁the ▁interpretation ▁of ▁Rule ▁ 1 9 ▁of ▁our ▁Rules ▁of ▁Procedure .
# ▁The ▁support ▁of ▁the ▁British ▁Conservatives ▁once ▁again ▁clearly ▁shows ▁the ▁untenable ▁association ▁of ▁this ▁group ▁with ▁the ▁European ▁People ’ s ▁Party ▁tradition , ▁so ▁well ▁represented ▁by ▁Mrs ▁Gross et ê te ▁and ▁also ▁by ▁Mrs ▁Avil é s ▁Perea .
# ---
# ▁Nonostante ▁questo ▁approccio ▁selettivo , ▁è ▁positivo ▁che ▁i ▁crimini ▁vengano ▁puniti , ▁anche ▁se ▁si ▁tenta ▁di ▁giustifica rli ▁in ▁termini ▁di ▁esigenze ▁di ▁guerra .
# ▁Ho ▁ricevuto ▁una ▁richiesta ▁dall ' onorevole ▁Hannan ▁per ▁un ▁punto ▁riguardante ▁l ' interpretazione ▁dell ' articolo ▁ 1 9 ▁del ▁nostro ▁regolamento .
# ▁L ’ adesione ▁dei ▁conservatori ▁britannici ▁rende ▁ancora ▁una ▁volta ▁evidente ▁l ’ insostenibile ▁convivenza ▁di ▁questo ▁gruppo ▁con ▁la ▁tradizione ▁popolare ▁europea , ▁così ▁ben ▁rappresentata ▁dalla ▁collega ▁Grosset ê te ▁e ▁anche ▁dalla ▁collega ▁Avilés ▁Perea .

# %%
# Split the dataset into training set, development set, and test set
# Development and test sets should be between 1000 and 5000 segments (here we chose 2000)
# !python3 MT-Preparation/train_dev_split/train_dev_test_split.py 4000 4000 Europarl.en-it.it-filtered.it.subword Europarl.en-it.en-filtered.en.subword
# Out:
# Dataframe shape: (1889521, 2)
# --- Empty Cells Deleted --> Rows: 1889521
# --- Wrote Files
# Done!
# Output files
# Europarl.en-it.it-filtered.it.subword.train
# Europarl.en-it.en-filtered.en.subword.train
# Europarl.en-it.it-filtered.it.subword.dev
# Europarl.en-it.en-filtered.en.subword.dev
# Europarl.en-it.it-filtered.it.subword.test
# Europarl.en-it.en-filtered.en.subword.test

# %%
# Line count for the subworded train, dev, test datatest
# !wc -l *.subword.*
# Out:
#      4000 Europarl.en-it.en-filtered.en.subword.dev
#      4000 Europarl.en-it.en-filtered.en.subword.test
#   1881521 Europarl.en-it.en-filtered.en.subword.train
#      4000 Europarl.en-it.it-filtered.it.subword.dev
#      4000 Europarl.en-it.it-filtered.it.subword.test
#   1881521 Europarl.en-it.it-filtered.it.subword.train
#   3779042 total

# %%
# Check the first and last line from each dataset

# -------------------------------------------
# Change this cell to print your name
# !echo -e "My name is: Manuel Piessalbo \n"
# -------------------------------------------

# !echo "---First line---"
# !head -n 1 *.{train,dev,test}

# !echo -e "\n---Last line---"
# !tail -n 1 *.{train,dev,test}
# Out:
# My name is: Manuel Piessalbo
#
# ---First line---
# ==> Europarl.en-it.en-filtered.en.subword.train <==
# ▁Despite ▁that ▁selective ▁approach , ▁it ▁is ▁good ▁that ▁crimes ▁should ▁be ▁punished , ▁even ▁if ▁an ▁attempt ▁is ▁made ▁to ▁justify ▁them ▁in ▁terms ▁of ▁the ▁exigencies ▁of ▁war .
#
# ==> Europarl.en-it.it-filtered.it.subword.train <==
# ▁Nonostante ▁questo ▁approccio ▁selettivo , ▁è ▁positivo ▁che ▁i ▁crimini ▁vengano ▁puniti , ▁anche ▁se ▁si ▁tenta ▁di ▁giustifica rli ▁in ▁termini ▁di ▁esigenze ▁di ▁guerra .
#
# ==> Europarl.en-it.en-filtered.en.subword.dev <==
# ▁The ▁explanatory ▁statement ▁is ▁very ▁precise ▁in ▁describing ▁what ▁is ▁happening ▁at ▁the ▁moment , ▁namely ▁that ▁judicial ▁cooperation ▁is ▁being ▁in stitutionalised ▁or , ▁to ▁put ▁it ▁more ▁accurately , ▁that ▁there ▁is ▁a ▁trend ▁towards ▁ supranationalism ▁in ▁this ▁area .
#
# ==> Europarl.en-it.it-filtered.it.subword.dev <==
# ▁Nella ▁motivazione ▁si ▁descrive ▁con ▁grande ▁precisione ▁che ▁ci ▁troviamo ▁di ▁fronte ▁alla ▁istituzionali zzazione ▁della ▁cooperazione ▁giudiziaria , ▁o ▁per ▁meglio ▁dire ▁di ▁fronte ▁alla ▁tendenza ▁a ▁renderla ▁sovranazionale .
#
# ==> Europarl.en-it.en-filtered.en.subword.test <==
# ▁I ▁very ▁much ▁like ▁the ▁way ▁the ▁European ▁Parliament ▁and ▁the ▁Council ▁have ▁described ▁the ▁goals ▁of ▁intercultural ▁dialogue ▁in ▁their ▁decision ▁No ▁ 1 9 8 3 / 2 0 0 6 / EC , ▁which ▁established ▁the ▁European ▁ Y ear ▁' to ▁strengthen ▁respect ▁for ▁cultural ▁diversity ▁and ▁deal ▁with ▁the ▁complex ▁reality ▁in ▁our ▁societies ▁and ▁the ▁coexistence ▁of ▁different ▁cultural ▁identities ▁and ▁beliefs .
#
# ==> Europarl.en-it.it-filtered.it.subword.test <==
# ▁Apprezzo ▁molto ▁il ▁modo ▁in ▁cui ▁il ▁Parlamento ▁europeo ▁e ▁il ▁Consiglio ▁hanno ▁descritto ▁gli ▁obiettivi ▁del ▁dialogo ▁interculturale ▁nella ▁decisione ▁ 1 9 8 3 / 2 0 0 6 / CE , ▁che ▁ha ▁istituito ▁l ' Anno ▁europeo ▁" per ▁rafforzare ▁il ▁rispetto ▁della ▁diversità ▁culturale ▁e ▁rispondere ▁alle ▁complesse ▁esigenze ▁delle ▁nostre ▁società ▁e ▁della ▁coesistenza ▁di ▁identità ▁culturali ▁e ▁credi ▁diversi .
#
# ---Last line---
# ==> Europarl.en-it.en-filtered.en.subword.train <==
# ▁If ▁the ▁Member ▁States ▁ratify ▁it ▁by ▁spring ▁ 2 0 0 9 , ▁Europe ▁will ▁finally ▁be ▁able ▁to ▁make ▁effective , ▁transparent ▁and ▁democratic ▁decisions ▁in ▁areas ▁such ▁as ▁security , ▁growth , ▁energy , ▁climate ▁change ▁and ▁demographics .
#
# ==> Europarl.en-it.it-filtered.it.subword.train <==
# ▁Se ▁gli ▁Stati ▁membri ▁lo ▁ratificheranno ▁entro ▁la ▁primavera ▁del ▁ 2 0 0 9 , ▁l ' Europa ▁potrà ▁infine ▁adottare ▁decisioni ▁in ▁modo ▁efficace , ▁trasparente ▁e ▁democratico ▁in ▁settori ▁quali ▁la ▁sicurezza , ▁la ▁crescita , ▁l ' energia , ▁il ▁clima ▁e ▁la ▁demografia .
#
# ==> Europarl.en-it.en-filtered.en.subword.dev <==
# ▁However , ▁I ▁regret ▁that ▁Amendments ▁Nos ▁ 1 1 , ▁ 1 4 ▁and ▁ 1 5 ▁cannot ▁be ▁accepted .
#
# ==> Europarl.en-it.it-filtered.it.subword.dev <==
# ▁Mi ▁dispiace ▁però ▁che ▁gli ▁emendamenti ▁n . ▁ 1 1 , ▁ 1 4 ▁e ▁ 1 5 ▁non ▁possano ▁essere ▁accettati .
#
# ==> Europarl.en-it.en-filtered.en.subword.test <==
# ▁Why ▁not ▁look ▁at ▁them ▁too ?
#
# ==> Europarl.en-it.it-filtered.it.subword.test <==
# ▁Perché ▁non ▁prenderle ▁in ▁considerazione ?

# %%
# Copy your data to your Google Drive
# !cp -R /content/nmt2/ /content/drive/MyDrive/NLP_Project/en_it/it_to_en
